# %% [markdown]
# <a href="https://colab.research.google.com/github/monicasenna/movasc_scripts/blob/main/Precip_mensal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar bibliotecas necessárias
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Carregar dados (substitua 'dados_precipitacao.csv' pelo nome do seu arquivo)
# O arquivo deve conter ao menos duas colunas: 'data' e 'precipitacao'
df = pd.read_csv('/content/drive/MyDrive/Movasc2/lat-23.42_lon-46.02.csv')
df
# Out:
#              data    pr
# 0      1961-01-01   5.8
# 1      1961-01-02  27.5
# 2      1961-01-03  16.0
# 3      1961-01-04   1.8
# 4      1961-01-05   3.6
# ...           ...   ...
# 23085  2024-03-16   0.0
# 23086  2024-03-17   6.4
# 23087  2024-03-18  16.2
# 23088  2024-03-19  16.1
# 23089  2024-03-20  11.0
#
# [23090 rows x 2 columns]

# %%
# Converter a coluna de data para o tipo datetime
df['data'] = pd.to_datetime(df['data'])
# Definir a coluna de data como índice (opcional, mas útil para o resample)
df.set_index('data', inplace=True)
# Agrupar por mês e somar a precipitação
# Isso transforma dados diários em totais mensais
df_mensal = df.resample('M').sum()
# Exibir os dados mensais
print(df_mensal.head())
# Out:
#                pr
# data
# 1961-01-31  155.8
# 1961-02-28  167.4
# 1961-03-31  135.1
# 1961-04-30   96.3
# 1961-05-31   33.5
# <ipython-input-95-98c5053a1d19>:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_mensal = df.resample('M').sum()

# %%
# Salvar o resultado em um novo CSV, se desejar
df_mensal.to_csv('/content/drive/MyDrive/Movasc2/p_mensal_lat-23.42_lon-46.02.csv')
